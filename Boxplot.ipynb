# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load dataset
kashti = sns.load_dataset("titanic")

# Draw a box plot with a gradient palette
sns.boxplot(x="class", y="fare", hue="sex", data=kashti, palette="viridis", saturation=0.7)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(style='whitegrid')
# Load the 'tips' dataset
tips = sns.load_dataset("tips")

# Draw a box plot with a gradient palette
sns.barplot(x="day", y="tip", hue="sex", data=tips, saturation=1)

plt.show()

# %%
import seaborn as sns
import pandas as pf
import matplotlib.pyplot as plt
import numpy as np
sns.set(style='whitegrid')
# Load the 'tips' dataset
tips = sns.load_dataset("tips")
tips.describe()
# # Draw a box plot with a gradient palette
# sns.barplot(x="day", y="tip", hue="sex", data=tips, saturation=1)

# plt.show()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns
import pandas as pf
import matplotlib.pyplot as plt
import numpy as np
sns.set(style='whitegrid')
# Load the 'tips' dataset
tips = sns.load_dataset("tips")

# # Draw a box plot with a gradient palette
sns.boxplot(x="tip", y="day", hue="smoker", palette ="Set2",data=tips,dodge=False)

plt.show()

# %%
import seaborn as sns
sns.set(style= 'whitegrid')
tip = sns.load_dataset ('tips')
tip

palette = ['#1edb1a','#e0ca02']
sns.boxplot(x="tip", y="day", hue="smoker", palette=palette,data=tips)
# how to manage individual color for hue
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load dataset
kashti = sns.load_dataset("titanic")
# kashti.head()
# Draw a box plot with a gradient palette
sns.boxplot(x="sex", y="fare", data=kashti)

plt.show()

# %%
# Draw a box plot with a gradient palette
sns.boxplot(x="survived", y="age", data=kashti)

plt.show()

# %%
# Draw a box plot with a gradient palette
sns.boxplot(x="survived", y="age",showmeans=True, data=kashti)

plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
kashti = sns.load_dataset ("titanic")
sns.boxplot(x= "survived",
y="age", showmeans=True,
meanprops={"marker": "+",
            "markersize":"12",
            "markeredgecolor":"red"},
            data= kashti)

plt.xlabel("Hello", size = 12)
plt.ylabel("Age (years)", size=14),
plt.title("Box plot of kitnay doobay or kitnay bach gaye", size=16, weight="bold")
plt.show()

# facet wrap and facet  grid?
